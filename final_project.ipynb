# %%
import pandas as pd
import altair as alt
import numpy as np
from sklearn import set_config
from sklearn.compose import make_column_transformer
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    cross_validate,
    train_test_split,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
alt.data_transformers.enable('vegafusion')
set_config(transform_output="pandas")

# %%
url = 'https://drive.google.com/uc?export=download&id=1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz'

players = pd.read_csv(url)
players = players.drop(columns = ['individualId', 'organizationName', 'hashedEmail', 'subscribe', 'name']) #drop unnecessary columns
players
# Out:
#     experience  played_hours             gender  age
# 0          Pro          30.3               Male    9
# 1      Veteran           3.8               Male   17
# 2      Veteran           0.0               Male   17
# 3      Amateur           0.7             Female   21
# 4      Regular           0.1               Male   21
# ..         ...           ...                ...  ...
# 191    Amateur           0.0             Female   17
# 192    Veteran           0.3               Male   22
# 193    Amateur           0.0  Prefer not to say   17
# 194    Amateur           2.3               Male   17
# 195        Pro           0.2              Other   91
#
# [196 rows x 4 columns]

# %%
mean_hours_played = players['played_hours'].mean()
mean_hours_played
# Out:
# np.float64(5.845918367346939)

# %%
mean_hours_hist = alt.Chart(players).mark_bar().encode(
    x=alt.X('played_hours').title('Hours Played').bin(maxbins=30),
    y=alt.Y('count()')
)

mean_hours_hist
# Out:
# alt.Chart(...)

# %% [markdown]
# Mean hours played is 5.84 but you can see most players play less than 10 hours
# Indicates that data is very right tailed: large data contributors likely are below the mean anyway due to outliers significantly dragging up the mean.
# Therefore I will choose significant data collection to be >3 hours played.  (can change if we wanna make it lower but I don't think we should make it any higher.)

# %%
np.random.seed(424242)
players = players.assign(high_contributor = players['played_hours'] >= 3)
players
# Out:
#     experience  played_hours             gender  age  high_contributor
# 0          Pro          30.3               Male    9              True
# 1      Veteran           3.8               Male   17              True
# 2      Veteran           0.0               Male   17             False
# 3      Amateur           0.7             Female   21             False
# 4      Regular           0.1               Male   21             False
# ..         ...           ...                ...  ...               ...
# 191    Amateur           0.0             Female   17             False
# 192    Veteran           0.3               Male   22             False
# 193    Amateur           0.0  Prefer not to say   17             False
# 194    Amateur           2.3               Male   17             False
# 195        Pro           0.2              Other   91             False
#
# [196 rows x 5 columns]

# %%
train, test = train_test_split(players, test_size = 0.3)

X = train[['age']]
y = train['high_contributor']

X_test = test[['age']]
y_test = test['high_contributor']

# %%
#cross validation

param_grid = {
    'n_neighbors': range(2, 15, 1)
}

pipeline = KNeighborsClassifier()

knn_tune_grid = GridSearchCV(
    estimator=pipeline, param_grid=param_grid, cv=5, return_train_score=True, n_jobs=-1)

model_grid = knn_tune_grid.fit(X, y)
accuracies_grid = pd.DataFrame(model_grid.cv_results_)

cross_val_plot = alt.Chart(accuracies_grid).mark_line(point=True).encode(
    x=alt.X('param_n_neighbors').title('KNN Number of Neighbours').scale(zero=False),
    y=alt.Y('mean_test_score').title('Accuracy Estimate').scale(zero=False)
)

cross_val_plot
# Out:
# alt.Chart(...)

# %%
# make classifier
spec = KNeighborsClassifier(n_neighbors=4)

preprocessor = make_column_transformer((StandardScaler(), ['age']))

pipe = make_pipeline(preprocessor, spec)
                    
fit = pipe.fit(X, y)

# %%
# predict high contributor 

contribution_df = test.assign(
    predicted = pipe.predict(X_test)
)

contribution_df
# Out:
#     experience  played_hours             gender  age  high_contributor  \
# 177    Veteran           2.7         Non-binary   21             False
# 9      Veteran           0.0             Female   22             False
# 150    Amateur           0.0               Male   17             False
# 35     Veteran           0.4               Male   20             False
# 119   Beginner           0.0               Male   23             False
# 117    Amateur           0.0  Prefer not to say   17             False
# 173    Regular           0.0               Male   50             False
# 126   Beginner           0.7             Female   24             False
# 115    Regular           0.1               Male   24             False
# 2      Veteran           0.0               Male   17             False
# 1      Veteran           3.8               Male   17              True
# 54    Beginner           0.0             Female   42             False
# 135    Veteran           0.0               Male   21             False
# 165    Regular           0.1               Male   21             False
# 174    Veteran           0.0               Male   17             False
# 62         Pro           1.0               Male   17             False
# 14     Veteran           0.0         Non-binary   17             False
# 68     Regular           0.1               Male   15             False
# 97     Veteran           0.1               Male   18             False
# 57     Regular           0.0               Male   17             False
# 140    Regular           0.0               Male   20             False
# 131    Amateur           0.0             Female   23             False
# 181    Amateur           0.8             Female   22             False
# 145    Veteran           0.1               Male   19             False
# 142   Beginner           1.0             Female   17             False
# 192    Veteran           0.3               Male   22             False
# 143    Veteran           0.1               Male   16             False
# 5      Amateur           0.0             Female   17             False
# 47     Regular           0.0  Prefer not to say   23             False
# 72     Veteran           0.0               Male   17             False
# 169    Veteran           0.1               Male   17             False
# 59     Veteran           0.2               Male   38             False
# 60     Veteran           0.0               Male   17             False
# 85     Amateur           0.0               Male   21             False
# 91    Beginner           0.0         Non-binary   17             False
# 46     Veteran           0.1               Male   17             False
# 23    Beginner           0.0               Male   17             False
# 49    Beginner           0.4  Prefer not to say   22             False
# 56     Amateur           2.9               Male   11             False
# 11         Pro           0.0               Male   17             False
# 107    Veteran           2.7             Female   22             False
# 127    Amateur           0.0               Male   21             False
# 81     Veteran           1.0         Non-binary   17             False
# 158    Regular         178.2             Female   19              True
# 8      Amateur           0.1               Male   17             False
# 136    Regular           0.0               Male   20             False
# 15     Amateur           0.0               Male   22             False
# 34    Beginner           0.6               Male   26             False
# 0          Pro          30.3               Male    9              True
# 116    Veteran           0.0  Prefer not to say   20             False
# 73     Veteran           0.0               Male   22             False
# 178    Amateur           0.4       Two-Spirited   17             False
# 170        Pro           0.4               Male   21             False
# 106    Regular           0.0               Male   23             False
# 130    Amateur          56.1               Male   23              True
# 98     Amateur           0.0  Prefer not to say   17             False
# 118    Veteran           0.0               Male   46             False
# 17     Amateur          48.4             Female   17              True
# 122    Amateur           0.1             Female   32             False
#
#      predicted
# 177      False
# 9        False
# 150      False
# 35       False
# 119      False
# 117      False
# 173      False
# 126      False
# 115      False
# 2        False
# 1        False
# 54       False
# 135      False
# 165      False
# 174      False
# 62       False
# 14       False
# 68       False
# 97       False
# 57       False
# 140      False
# 131      False
# 181      False
# 145      False
# 142      False
# 192      False
# 143      False
# 5        False
# 47       False
# 72       False
# 169      False
# 59       False
# 60       False
# 85       False
# 91       False
# 46       False
# 23       False
# 49       False
# 56       False
# 11       False
# 107      False
# 127      False
# 81       False
# 158      False
# 8        False
# 136      False
# 15       False
# 34       False
# 0        False
# 116      False
# 73       False
# 178      False
# 170      False
# 106      False
# 130      False
# 98       False
# 118      False
# 17       False
# 122      False

# %%
# crosstab

pd.crosstab(
    contribution_df['high_contributor'],
    contribution_df['predicted']
)
# Out:
# predicted         False
# high_contributor
# False                54
# True                  5
